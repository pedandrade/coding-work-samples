# %% [markdown]
# <hr style="height:1px;border:none;color:#333;background-color:#333;" />
# <hr style="height:1px;border:none;color:#333;background-color:#333;" />
# <br><br><br>
#
# <h1>Dynamic Email Generator Template</h1><br>
# DAT-5301 Data Science: Python<br>
# Prof. Chase Kusterer<br>
# Hult International Business School <br>
# <a href="https://github.com/chase-kusterer">https://github.com/chase-kusterer</a> <br><br><br><br><br>
#
# <hr style="height:1px;border:none;color:#333;background-color:#333;" />
# <hr style="height:1px;border:none;color:#333;background-color:#333;" />
# <br>
# <h3><u>Assignment Description</u></h3><br>
# In this assignment, you are tasked with developing a dynamic email generator that can loop over customer data and output personalized results. This is an opportunity for you to apply your knowledge of dynamic strings, lists, conditional statements, loops, and other critical coding structures in Python.
# <br><br>
#
# <strong>Primary Tasks</strong>
#
# 1. Complete the function template.
# 2. Work with the data provided to generate personalized emails for each customer.
#
# <br>
# Note: Don't forget to put your first and last name in the signature of your personalized emails!
# <br><br>
# <h3><u>Personalized Email Criteria</u></h3>
#
#
# * You are not allowed to alter any of the data provided (i.e., don't make changes to the provided lists).
# * Customers with no names should be given the name "Valued Customer".
# * Every conditional statement needs to have an else clause.
# * Your formatting should be the same as in the examples.
# * Make sure your code is well commented.
# * The following should be random:
#     * subject lines
#     * opening sentences
#     * promotion sentences
# * You should NOT use input() or ask users for any additional information.
# * Do NOT make any additional cells. Please use the ones provided.
#
# <br><br><br>
#
# <u><h3>Target Results</h3></u><br>
# Your results should be formatted as in the following examples:
#
# ~~~
# ----------------------------------------
# SUBJECT: Dining Room Tables We Can Barely Keep In Stock
# ----------------------------------------
#
# Greetings Mary!
#
# We noticed your interest in our Dining Room Tables.
#
# Order within the next 24 hours and get FINANCING AT 0% INTEREST!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== ===========(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# YOUR FIRST AND LAST NAME
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Area Rugs People Will Compliment
# ----------------------------------------
#
# Greetings Patrick!
#
# You have excellent taste in Area Rugs.
#
# Order within the next 24 hours and get A 30 DAY RETURN POLICY WITH NO STRINGS ATTACHED!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== ===========(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# YOUR FIRST AND LAST NAME
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Dining Room Tables You *Gotta* See.
# ----------------------------------------
#
# Greetings Gonzalo!
#
# You have excellent taste in Dining Room Tables.
#
# Order one today and get A 30 DAY RETURN POLICY WITH NO STRINGS ATTACHED!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== ===========(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# YOUR FIRST AND LAST NAME
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
# ----------------------------------------
# ~~~
#
# <br>
# <h3><u>Tips</u></h3><br>
# Check out the <a href="https://docs.python.org/3/library/random.html#random.choice">rand.choice()</a> method in order to randomize your subject lines, opening sentences, and promotion sentences.

# %%
# imports
import pandas as pd
import random as rand

# %% [markdown]
# <br>

# %%
# staff info (put your name here)
staff_name    = "Pedro Andrade"
staff_title   = "Customer Relationship Manager"
staff_company = "DAT-5301 DATA SCIENCE: PYTHON"

# %% [markdown]
# <br>
# <h3><u>Customer Information Data Structure</u></h3><br>
# The structure of the data in customer_info is as follows:
#
# ~~~
# [ FIRST NAME, RECOMMENDED PRODUCT CATEGORY, HOOK TAG ]
# ~~~

# %%
##############################################################################
# Note: You are NOT permitted to alter any of the data in this code cell     #
##############################################################################

# customer info
customer_info = [  ['mary', 'dining room tables', 'financing'],
                   ['patrick', 'area rugs', 'return policy'],
                   ['gonzalo', 'dining room tables', 'return policy'],
                   ['UNKNOWN', 'coffee tables', 'in-home assembly'],
                   ['richard', 'sofas', 'free shipping'],
                   ['UNKNOWN', 'dining room tables', 'in-home assembly'],
                   ['tim', 'sofas', 'return policy'],
                   ['keenan', 'area rugs', 'financing'],
                   ['UNKNOWN', 'area rugs', 'financing'],
                   ['dana', 'bookcases', 'customization'],
                   ['lauren', 'bookcases', 'customization'],
                   ['karen', 'sofas', 'in-home assembly'],  ]


# approved email subject lines
subject_lines    = [  "people will compliment",                 
                      "on our site are just WOW!",              
                      "you *gotta* see.",                       
                      "handpicked for you!",                    
                      "- Just for you, we rounded up our best", 
                      "we can barely keep in stock",            
                      "we found for you.",                      
                      "at a great price.",                      
                      "we think you will love",  ]


# approved hooks
hooks = [  "FREE Shipping",
           "Financing at 0% Interest",
           "In-Home Assembly for just $10",
           "A 30 Day Return Policy with No Strings Attached",
           "Discounted Pricing on Tailoring and Customizations",  ]



# approved openings
openings = [  f"We noticed your interest in our ",
              f"I'm glad you were checking out our ",
              f"You have excellent taste in ",  ]


# approved promotions
promotions = [
    f"Order within the next 24 hours and get ",
    f"Order one today and get ",
    f"Your order qualifies for ",  ]


# approved promotion code
promotion_code = "!\nJust use the promotion code PYTHON!"

# %% [markdown]
# <br>
# <h3>Complete the body of the function template below.</h3>

# %%
# defining a personalized email function
def dynamic_email():
    """
    This is a dynamic email generator. It takes no arguments, but the
    following data is required for it to work (should be defined globally):
    
    Note: Defined globally means that these should be defined outside of the
          body of the function. This has been done for you in the cells above.
    
    category       | str | recommended product category
    subject        | str | subject line message
    name           | str | name of a customer
    opening        | str | opening sentence in the body of the email
    promotion      | str | promotional sentence in the email
    hook           | str | mkting hook; part of the promotional sentence
    promotion_code | str | the code for customers to access their promotion
    """
    
    # character length
    print('-' * 40)
   

    # Subject line of the e-mail
    print(f"SUBJECT: {(product).title()} {rand.choice(subject_lines).title()}") 
    # character length
    print('-' * 40,"\n")

    # Greetings line
    print(f"""Greetings {(name).title()}!\n""")

    
    
    
    # email body
    print(f"""{rand.choice(openings)}{(product).title()}.\n
{rand.choice(promotions)}{(hook).upper()}{promotion_code}
    
                         ____                        
                        /    \                       
                       /______\                      
                          ||                         
           /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\   
          /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\  
         (_)========(_)   ||  (_)==== =======x====(_) 
          I|_________|I  _||_  |___________________| 
\n""")

    # Signature of the e-mail
    print(f"""Best,
{staff_name.upper()}
{staff_title}
{staff_company}\n\n""")
    # character length
    print('-' * 40, "\n\n")

# %% [markdown]
# <br>
# <h3>Write code to loop over the data. Use the data and information provided to develop your personalized emails.</h3><br>
# Note that the dynamic_email() function should be run at the very end of your loop. This part of the code has been provided for you.

# %%
# Tip: You should use a for loop to generate each email
# START YOUR LOOP HERE

for name, product, hook in customer_info:
   
    # Make sure to indent the body of your loop!
    
    # Changing UNKNOWN customer name to Valued Customer.
    if name == 'UNKNOWN':
        name = "Valued Customer"
    else:
        name = name
   
    
    # Conditional statements to relate hook tag to proper hook
    if hook == 'financing':
        hook = hooks[1]
    elif hook == 'return policy':
        hook = hooks[3]
    elif hook == 'in-home assembly':
        hook = hooks[2]
    elif hook == 'free shipping':
        hook = hooks[0]
    elif hook == 'customization':
        hook = hooks[4]
        
    # else statement to check for errors or unknown hook
    else:
        hook = 'A special gift from us!'
        
    
    # Keep this in the body of the loop.
    dynamic_email()
# Out:
# ----------------------------------------
# SUBJECT: Dining Room Tables - Just For You, We Rounded Up Our Best
# ----------------------------------------
#
# Greetings Mary!
#
# I'm glad you were checking out our Dining Room Tables.
#
# Order within the next 24 hours and get FINANCING AT 0% INTEREST!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Area Rugs You *Gotta* See.
# ----------------------------------------
#
# Greetings Patrick!
#
# I'm glad you were checking out our Area Rugs.
#
# Order one today and get A 30 DAY RETURN POLICY WITH NO STRINGS ATTACHED!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Dining Room Tables On Our Site Are Just Wow!
# ----------------------------------------
#
# Greetings Gonzalo!
#
# I'm glad you were checking out our Dining Room Tables.
#
# Your order qualifies for A 30 DAY RETURN POLICY WITH NO STRINGS ATTACHED!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Coffee Tables Handpicked For You!
# ----------------------------------------
#
# Greetings Valued Customer!
#
# I'm glad you were checking out our Coffee Tables.
#
# Order one today and get IN-HOME ASSEMBLY FOR JUST $10!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Sofas On Our Site Are Just Wow!
# ----------------------------------------
#
# Greetings Richard!
#
# You have excellent taste in Sofas.
#
# Order one today and get FREE SHIPPING!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Dining Room Tables On Our Site Are Just Wow!
# ----------------------------------------
#
# Greetings Valued Customer!
#
# We noticed your interest in our Dining Room Tables.
#
# Order one today and get IN-HOME ASSEMBLY FOR JUST $10!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Sofas Handpicked For You!
# ----------------------------------------
#
# Greetings Tim!
#
# I'm glad you were checking out our Sofas.
#
# Order one today and get A 30 DAY RETURN POLICY WITH NO STRINGS ATTACHED!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Area Rugs On Our Site Are Just Wow!
# ----------------------------------------
#
# Greetings Keenan!
#
# You have excellent taste in Area Rugs.
#
# Order within the next 24 hours and get FINANCING AT 0% INTEREST!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Area Rugs Handpicked For You!
# ----------------------------------------
#
# Greetings Valued Customer!
#
# I'm glad you were checking out our Area Rugs.
#
# Order one today and get FINANCING AT 0% INTEREST!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Bookcases We Can Barely Keep In Stock
# ----------------------------------------
#
# Greetings Dana!
#
# You have excellent taste in Bookcases.
#
# Order within the next 24 hours and get DISCOUNTED PRICING ON TAILORING AND CUSTOMIZATIONS!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Bookcases We Found For You.
# ----------------------------------------
#
# Greetings Lauren!
#
# I'm glad you were checking out our Bookcases.
#
# Order one today and get DISCOUNTED PRICING ON TAILORING AND CUSTOMIZATIONS!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Sofas We Found For You.
# ----------------------------------------
#
# Greetings Karen!
#
# We noticed your interest in our Sofas.
#
# Order one today and get IN-HOME ASSEMBLY FOR JUST $10!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------

# %% [markdown]
# <br>
