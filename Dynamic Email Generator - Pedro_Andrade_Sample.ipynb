# %% [markdown]
# This notebook is the result of an assignment provided by professor Chase Kusterer, from Hult International Business School.

# %%
# imports
import pandas as pd
import random as rand

# %% [markdown]
# # My info

# %%
# staff info 
staff_name    = "Pedro Andrade"
staff_title   = "Customer Relationship Manager"
staff_company = "DAT-5301 DATA SCIENCE: PYTHON"

# %% [markdown]
# # Lists

# %%
# customer info
customer_info = [  ['mary', 'dining room tables', 'financing'],
                   ['patrick', 'area rugs', 'return policy'],
                   ['gonzalo', 'dining room tables', 'return policy'],
                   ['UNKNOWN', 'coffee tables', 'in-home assembly'],
                   ['richard', 'sofas', 'free shipping'],
                   ['UNKNOWN', 'dining room tables', 'in-home assembly'],
                   ['tim', 'sofas', 'return policy'],
                   ['keenan', 'area rugs', 'financing'],
                   ['UNKNOWN', 'area rugs', 'financing'],
                   ['dana', 'bookcases', 'customization'],
                   ['lauren', 'bookcases', 'customization'],
                   ['karen', 'sofas', 'in-home assembly'],  ]


# email subject lines
subject_lines    = [  "people will compliment",                 
                      "on our site are just WOW!",              
                      "you *gotta* see.",                       
                      "handpicked for you!",                    
                      "- Just for you, we rounded up our best", 
                      "we can barely keep in stock",            
                      "we found for you.",                      
                      "at a great price.",                      
                      "we think you will love",  ]


# hooks
hooks = [  "FREE Shipping",
           "Financing at 0% Interest",
           "In-Home Assembly for just $10",
           "A 30 Day Return Policy with No Strings Attached",
           "Discounted Pricing on Tailoring and Customizations",  ]



# openings
openings = [  f"We noticed your interest in our ",
              f"I'm glad you were checking out our ",
              f"You have excellent taste in ",  ]


# promotions
promotions = [
    f"Order within the next 24 hours and get ",
    f"Order one today and get ",
    f"Your order qualifies for ",  ]


# promotion code
promotion_code = "!\nJust use the promotion code PYTHON!"

# %% [markdown]
# # Function

# %%
# defining a personalized email function
def dynamic_email():
    """
    This is a dynamic email generator. It takes no arguments, but the
    following data is required for it to work (should be defined globally):
    
    category       | str | recommended product category
    subject        | str | subject line message
    name           | str | name of a customer
    opening        | str | opening sentence in the body of the email
    promotion      | str | promotional sentence in the email
    hook           | str | mkting hook; part of the promotional sentence
    promotion_code | str | the code for customers to access their promotion
    """
    
    # character length
    print('-' * 40)
   

    # Subject line of the e-mail
    print(f"SUBJECT: {(product).title()} {rand.choice(subject_lines).title()}") 
    # character length
    print('-' * 40,"\n")

    # Greetings line
    print(f"""Greetings {(name).title()}!\n""")

    
    
    
    # email body
    print(f"""{rand.choice(openings)}{(product).title()}.\n
{rand.choice(promotions)}{(hook).upper()}{promotion_code}
    
                         ____                        
                        /    \                       
                       /______\                      
                          ||                         
           /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\   
          /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\  
         (_)========(_)   ||  (_)==== =======x====(_) 
          I|_________|I  _||_  |___________________| 
\n""")

    # Signature of the e-mail
    print(f"""Best,
{staff_name.upper()}
{staff_title}
{staff_company}\n\n""")
    # character length
    print('-' * 40, "\n\n")

# %% [markdown]
# # Generating Dynamic E-mail

# %%
for name, product, hook in customer_info:
   
    # Make sure to indent the body of your loop!
    
    # Changing UNKNOWN customer name to Valued Customer.
    if name == 'UNKNOWN':
        name = "Valued Customer"
    else:
        name = name
   
    
    # Conditional statements to relate hook tag to proper hook
    if hook == 'financing':
        hook = hooks[1]
    elif hook == 'return policy':
        hook = hooks[3]
    elif hook == 'in-home assembly':
        hook = hooks[2]
    elif hook == 'free shipping':
        hook = hooks[0]
    elif hook == 'customization':
        hook = hooks[4]
        
    # else statement to check for errors or unknown hook
    else:
        hook = 'A special gift from us!'
        
    

    dynamic_email()
# Out:
# ----------------------------------------
# SUBJECT: Dining Room Tables - Just For You, We Rounded Up Our Best
# ----------------------------------------
#
# Greetings Mary!
#
# You have excellent taste in Dining Room Tables.
#
# Order one today and get FINANCING AT 0% INTEREST!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Area Rugs People Will Compliment
# ----------------------------------------
#
# Greetings Patrick!
#
# We noticed your interest in our Area Rugs.
#
# Your order qualifies for A 30 DAY RETURN POLICY WITH NO STRINGS ATTACHED!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Dining Room Tables People Will Compliment
# ----------------------------------------
#
# Greetings Gonzalo!
#
# I'm glad you were checking out our Dining Room Tables.
#
# Order within the next 24 hours and get A 30 DAY RETURN POLICY WITH NO STRINGS ATTACHED!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Coffee Tables You *Gotta* See.
# ----------------------------------------
#
# Greetings Valued Customer!
#
# I'm glad you were checking out our Coffee Tables.
#
# Your order qualifies for IN-HOME ASSEMBLY FOR JUST $10!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Sofas People Will Compliment
# ----------------------------------------
#
# Greetings Richard!
#
# You have excellent taste in Sofas.
#
# Your order qualifies for FREE SHIPPING!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Dining Room Tables You *Gotta* See.
# ----------------------------------------
#
# Greetings Valued Customer!
#
# You have excellent taste in Dining Room Tables.
#
# Your order qualifies for IN-HOME ASSEMBLY FOR JUST $10!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Sofas We Found For You.
# ----------------------------------------
#
# Greetings Tim!
#
# You have excellent taste in Sofas.
#
# Order one today and get A 30 DAY RETURN POLICY WITH NO STRINGS ATTACHED!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Area Rugs - Just For You, We Rounded Up Our Best
# ----------------------------------------
#
# Greetings Keenan!
#
# You have excellent taste in Area Rugs.
#
# Order within the next 24 hours and get FINANCING AT 0% INTEREST!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Area Rugs People Will Compliment
# ----------------------------------------
#
# Greetings Valued Customer!
#
# You have excellent taste in Area Rugs.
#
# Your order qualifies for FINANCING AT 0% INTEREST!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Bookcases You *Gotta* See.
# ----------------------------------------
#
# Greetings Dana!
#
# You have excellent taste in Bookcases.
#
# Your order qualifies for DISCOUNTED PRICING ON TAILORING AND CUSTOMIZATIONS!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Bookcases Handpicked For You!
# ----------------------------------------
#
# Greetings Lauren!
#
# I'm glad you were checking out our Bookcases.
#
# Order within the next 24 hours and get DISCOUNTED PRICING ON TAILORING AND CUSTOMIZATIONS!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
#
#
# ----------------------------------------
# SUBJECT: Sofas - Just For You, We Rounded Up Our Best
# ----------------------------------------
#
# Greetings Karen!
#
# We noticed your interest in our Sofas.
#
# Your order qualifies for IN-HOME ASSEMBLY FOR JUST $10!
# Just use the promotion code PYTHON!
#
#                          ____
#                         /    \
#                        /______\
#                           ||
#            /~~~~~~~~\     ||    /~~~~~~~~~~~~~~~~\
#           /~ () ()  ~\    ||   /~ ()  ()  () ()  ~\
#          (_)========(_)   ||  (_)==== =======x====(_)
#           I|_________|I  _||_  |___________________|
#
#
# Best,
# PEDRO ANDRADE
# Customer Relationship Manager
# DAT-5301 DATA SCIENCE: PYTHON
#
#
# ----------------------------------------
